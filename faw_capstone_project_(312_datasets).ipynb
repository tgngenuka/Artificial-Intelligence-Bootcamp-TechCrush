# %% [markdown]
# <a href="https://colab.research.google.com/github/tgngenuka/Artificial-Intelligence-Bootcamp-TechCrush/blob/main/faw_capstone_project_(312_datasets).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 0: Setup and Environment Check
# This section imports necessary libraries and sets core parameters

# %%
# install/import necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import zipfile
from tensorflow.keras.models import load_model # Used for loading the best model


# Define core parameters
IMG_WIDTH = 224 # Standard size for MobileNetV2
IMG_HEIGHT = 224
BATCH_SIZE = 32
RANDOM_SEED = 42
EPOCHS = 15 # Increased to 15 to give the model more time to learn the 3 classes

# Set a seed for reproducibility
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# Step 1: Data Retrieval and Unzipping

# %%
# 1. Clone the GitHub repository
print("Cloning the GitHub repository...")
# !git clone https://github.com/mantle-bearer/FAW-Detection-Capstone

# Define paths based on the cloned repository structure
REPO_FOLDER = "FAW-Detection-Capstone"
ZIP_FILE_NAME = "fall armyworm identification.zip" # <-- CHECK THIS EXACT NAME!
DATA_ROOT_DIR = "fall armyworm identification" # Name of the folder where the data will be extracted

ZIP_FILE_PATH = os.path.join(REPO_FOLDER, ZIP_FILE_NAME)

# 2. Unzip the dataset
if os.path.exists(ZIP_FILE_PATH):
    print(f"Unzipping {ZIP_FILE_NAME}...")
    with zipfile.ZipFile(ZIP_FILE_PATH, 'r') as zip_ref:
        # Extracts to a folder named 'fa_detection_data' which should contain 'train' and 'validation'
        zip_ref.extractall(DATA_ROOT_DIR)
    print("Unzipping complete.")
else:
    print(f"Error: Zip file not found at {ZIP_FILE_PATH}. Please check the file path inside your GitHub repo.")
# Out:
# Cloning the GitHub repository...
# fatal: destination path 'FAW-Detection-Capstone' already exists and is not an empty directory.
# Unzipping fall armyworm identification.zip...
# Unzipping complete.

# %% [markdown]
# Step 2: Load Data and Create Datasets

# %%
# Assume your data is now structured as:
# fall armyworm identification/
# ├── fall armyworm identification/
# │   ├── train/
# │   │   ├── image1.jpg
# │   │   ├── image2.webp
# │   │   └── _classes.csv
# │   └── valid/
# │       ├── image3.jpg
# │       ├── image4.webp
# │       └── _classes.csv

# Function to get list of image files
def get_image_files(directory):
    image_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.webp')):
                image_files.append(os.path.join(root, file))
    return image_files

TRAIN_DIR = os.path.join(DATA_ROOT_DIR, 'fall armyworm identification', 'train')
VALIDATION_DIR = os.path.join(DATA_ROOT_DIR, 'fall armyworm identification', 'valid')

# Get list of image files
train_image_files = get_image_files(TRAIN_DIR)
val_image_files = get_image_files(VALIDATION_DIR)

# Print the number of files found to verify
print(f"Found {len(train_image_files)} training image files.")
print(f"Found {len(val_image_files)} validation image files.")


# Example (assuming class name is the first part of the filename before '_'):
def get_label_from_filename(filename):
    # This is a placeholder - replace with your actual logic
    class_name = os.path.basename(filename).split('_')[0]
    return class_name

# Create datasets from file paths
train_labels = [get_label_from_filename(f) for f in train_image_files]
val_labels = [get_label_from_filename(f) for f in val_image_files]

# Get unique class names
CLASS_NAMES = sorted(list(set(train_labels + val_labels)))
NUM_CLASSES = len(CLASS_NAMES)
print(f"Detected Classes: {CLASS_NAMES}")

# Create TensorFlow Datasets (you'll need to implement the loading and decoding)
# This is a placeholder and needs to be replaced with actual image loading and label encoding
train_ds = tf.data.Dataset.from_tensor_slices((train_image_files, train_labels))
val_ds = tf.data.Dataset.from_tensor_slices((val_image_files, val_labels))

# You will need to add mapping functions to load images and convert labels to categorical
# Example (needs to be implemented):
# def load_image_and_label(image_path, label):
#     # Load image, decode, resize, etc.
#     # Convert label to one-hot encoding
#     return image, one_hot_label

# train_ds = train_ds.map(load_image_and_label)
# val_ds = val_ds.map(load_image_and_label)

# Add batching and prefetching
# train_ds = train_ds.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)
# val_ds = val_ds.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 312 training image files.
# Found 32 validation image files.
# Detected Classes: ['', '0314F1-3241a-1540x800', '0d1ed5d9-a179-4b84-9126-5b95d37279a3-AP19078163984841', '1', '1263061', '1599418', '1599890', '1600102', '1673029-Fall-Armyworm-e1497986879311', '200522-Fall-armyworm-pic-002-in-maize-scaled', '20180710-fall-armyworm', '20200224', '20220801', '210427-Fall-armyworm-pic-001', '29810', '360', '3939-15farmyworm', '3f50a063-af57-48cf-a23a-5f761a344cfe-large16x9', '40538', '4387031', '4387058', '48045734022', '49107', '5110009', '5361210-Fall-Armyworm-e1497986850347', '5485992', '5caaa99b50', '61348de63d0ab-image', 'AdobeStock', 'AgronomyNews', 'Army', 'Armyworm-1024x698-1', 'Armyworms', 'Armyworms-continue-their-relentless-attacks-on-crops-worldwide-', 'FAO', 'FAW', 'FAW-TN-1-', 'FAW-TN-2-', 'FAW-in-late-corn-3', 'FAW-larva-in-KRS-corn-1-4-2020', 'FAW2', 'FAWormsDenudedAlfalfaHay', 'Fall-Armyworm-larva', 'Fall-Armyworm-larva-JFD', 'Fall-army-worm', 'Fall-armyworm-1', 'Fall-armyworm-green', 'Fall-armyworm-update-F01', 'Fall-armyworm2', 'FallArmyWom1', 'FallArmyworm', 'GetStoredImage', 'IMG', 'ISC-fall-armyworm', 'ISCA-fall-armyworm', 'LABAUR4I3JIUNK7CKHVBGRPKRY', 'LM1021', 'Lawn-Armyworm-Spodoptera-mauritia-1', 'Mythimna-unipuncta', 'NQ301QO0VQHS1QDK0KCKUQY05QWK8QT0GQO0ZKV0HK6K4QD0HKBKIK30UQLSIKEKPQA06QV04QB0QK', 'S-frugiperda-larva-feeding-on-a-young-cotton-boll', 'SCR-20240421-bnku', 'SCR-20240421-chfe', 'TurfAug22-TCArmyWorms-Feature', 'U7ZT2CVNWRX7VQZE2YTG7WEK4A', 'YOUNG-fall', 'ZL8ZSLGZ4LBHNHLR5HDH5HTH5HOHKLDHGHAH2HBZSLOHSLCHKL6ZLL5ZMHPZ0L6Z7H8ZZL6Z4LWZWHYH8LEZ0LTHNHLR', 'african-armyworm-spodoptera-exempta-caterpillars-on-damaged-maize-B7BCN2', 'army4', 'armyworm', 'armyworm-1-650x488', 'armyworm-copy', 'armyworm-copy-2', 'armyworm-on-plant-960', 'armyworm-soap-flush-Caleb-Kearney', 'armyworm-t63p61-Kansas-State-University', 'armyworm2-24', 'armyworms-in-texas-600x400', 'armyworms-spodoptera-spp-can-be-easily-identifi', 'armywormsdev', 'armywormsplit-screen1280x720', 'banner-fall-armyworm-6-1200x799', 'common', 'csm', 'dscn3849s80x45tm', 'ezgif-2-c7f402c52f', 'ezgif-2-cf508a23f2', 'ezgif-3-4ad299182c', 'ezgif-3-e2b3e63c35', 'ezgif-6-7b04a71e3e', 'ezgif-7-5c7628e863', 'fall', 'fall-army-catepillers', 'fall-army-larvae2-big', 'fall-army-worm-on-potato-1-', 'fall-army-worm-on-potato-4-', 'fall-army-worm-on-potato-5-', 'fall-army-worm-on-potato-6-', 'fall-armyworm', 'fall-armyworm-2017-uaex', 'fall-armyworm-IMG', 'fall-armyworm-Pat-Porter-2016', 'fall-armyworm-do4n', 'fall-armyworm-fig1', 'fall-armyworm-larva', 'fall-armyworm-on-grass-blade', 'fall-armyworm-spodoptera-frugiperda-on-600nw-1444285085', 'fallarmyworm2', 'faw-800x400', 'faw-different-colours-same-field', 'faw-news-large', 'faw1', 'fawJPG', 'first', 'grubs', 'image', 'image1170x530cropped', 'images', 'img321', 'istockphoto-1163856076-612x612', 'shutterstock', 'sweetcorn', 'worms']

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
# Inspect the extracted directory to understand the structure
print(f"Contents of {DATA_ROOT_DIR}:")
# !ls -R "{DATA_ROOT_DIR}"
# Out:
# Contents of fall armyworm identification:
# 'fall armyworm identification':
# 'fall armyworm identification'
#
# 'fall armyworm identification/fall armyworm identification':
# README.dataset.txt  README.roboflow.txt  test  train  valid
#
# 'fall armyworm identification/fall armyworm identification/test':
# 309911923_1-6-555x370_jpg.rf.7c63d158a18e77cc53518ad49b031aa6.jpg
# 8_fawheadcapsule_jpg.rf.46ccbf7fda7ff989fb99c1c858d63d20.jpg
# armyworm-1_jpg.rf.53d03dec32236aba85cd447d72effb5b.jpg
# armyworm-3_jpg.rf.42ac795eb3b1f2845789ba1238a7a621.jpg
# Armyworm-on-corn-1024x535_jpg.rf.c19efd7ad5b0f67da491579ce73f6d5a.jpg
# blog-2_webp.rf.df660ca156e9adc40e93bd19571c3a31.jpg
# _classes.csv
# ezgif-3-4d201179e1_webp.rf.daa3f3a768d8e644164537e76c217ba0.jpg
# ezgif-7-98e0c5a943_jpg.rf.9b023ed68e14609779d725ad22931141.jpg
# Fall-armyworm-identification-colors_jpg.rf.120ccddef8c67a57904d8e3fc11d0818.jpg
# fall_armyworm_russ_ottens_ipmimages_jpg.rf.4b4eb0b2a04be7bef17f71cb5a7cfd1b.jpg
# FAW-damage-to-sod-farm-1024x768_jpg.rf.06d353bfddd75f5d3099a40031f30f42.jpg
# fawweb_1_jpg.rf.f6f3ede024ff6a94196d73ab5168ba2f.jpg
# Figure-12_jpg.rf.f46ebbb3b7bdbe175140fe6f670e964e.jpg
# SEI_93616890_webp.rf.939b53a7fb2180d731150aa654bfbabc.jpg
# spodoptera-army-worm_jpg.rf.fcd7a3b27e5f59c59d9bf4c46d8b8936.jpg
# true_armyworm_lv_multi_ms_jpg.rf.2354277f136d409558a254ad64b2f20c.jpg
# Untitled-3_png.rf.2356ff2e550c79383993b65c89c4de4f.jpg
#
# 'fall armyworm identification/fall armyworm identification/train':
# 0314F1-3241a-1540x800_jpg.rf.131d4ce0774eabc185552fbb82809896.jpg
# 0314F1-3241a-1540x800_jpg.rf.2be0aac736290a1fee562ada4a337824.jpg
# 0314F1-3241a-1540x800_jpg.rf.b5630475cabf16d84501549ce357f804.jpg
# 0d1ed5d9-a179-4b84-9126-5b95d37279a3-AP19078163984841_webp.rf.2a0190bec12ea4c3ac87860762100b45.jpg
# 0d1ed5d9-a179-4b84-9126-5b95d37279a3-AP19078163984841_webp.rf.640f98b9129d8e365c11577479c992a1.jpg
# 0d1ed5d9-a179-4b84-9126-5b95d37279a3-AP19078163984841_webp.rf.8202e500a7bf55c6cdfd0c0e645e85e0.jpg
# 1263061_jpg.rf.42fa6bf554e51fac499d020ca8db8145.jpg
# 1263061_jpg.rf.992395be07cd6d638c757ef2141f13bf.jpg
# 1263061_jpg.rf.bf99bf4580d646086b94b971b12d2934.jpg
# 1599418_jpg.rf.3b7cca5886d41037e25a5fb34f595998.jpg
# 1599418_jpg.rf.d5bc502367985398f70e8ca73d7ffaac.jpg
# 1599418_jpg.rf.dac9d097a12557da51481f0a022183c8.jpg
# 1599890_jpg.rf.2b18cc5c85000c3b57ca5b963adce073.jpg
# 1599890_jpg.rf.7be5b8b716f2a5ffa4a3e32841d2ae83.jpg
# 1599890_jpg.rf.86c5aabe4f3ce839b671077d6e4004aa.jpg
# 1673029-Fall-Armyworm-e1497986879311_jpg.rf.096b2f2ce0353b1213e1ee575a282028.jpg
# 1673029-Fall-Armyworm-e1497986879311_jpg.rf.c13b0ec36bd86f37e520d7649eab7d3a.jpg
# 1673029-Fall-Armyworm-e1497986879311_jpg.rf.e4b6fb97679660c855ae5ba74cbb00cf.jpg
# 1_webp.rf.5ed88f8ebfe53a08961d0f4216fafc72.jpg
# 1_webp.rf.7fd5f2c187e022071d7a829867ead460.jpg
# 1_webp.rf.99f8f4207406c57cc94d84849f725eaf.jpg
# 20180710-fall-armyworm_png.rf.0dfcaa27c635185619de9113b3591d94.jpg
# 20180710-fall-armyworm_png.rf.50684cc21b2dfa328ccedf8fb3abd41e.jpg
# 20180710-fall-armyworm_png.rf.9539a89d1a3a2da55b132415e2a68c6e.jpg
# 20200224_125621-600x360_jpg.rf.240c5858eeb38473dcf1c3475edc54c4.jpg
# 20200224_125621-600x360_jpg.rf.9e570e926b033ee015c7e22a24309548.jpg
# 20200224_125621-600x360_jpg.rf.f9c56b354a243116fc55d52def493bc8.jpg
# 20220801_armyworm_jpg.rf.143c12ab0268c321b69552375d6026ab.jpg
# 20220801_armyworm_jpg.rf.17b748857e870009936bd4d457c991f7.jpg
# 20220801_armyworm_jpg.rf.601f5b18be3e831712951a02b466abc8.jpg
# 210427-Fall-armyworm-pic-001_jpg.rf.1254d6888ae374a2a693e701b91c7c4b.jpg
# 210427-Fall-armyworm-pic-001_jpg.rf.8c4481623f0ed39fbfbd7c11274e97ff.jpg
# 210427-Fall-armyworm-pic-001_jpg.rf.dbdf023e759a352d29d2c05c39f413e0.jpg
# 29810_04_jpg.rf.084f75b4115c4fe2f89b907b838c8118.jpg
# 29810_04_jpg.rf.51ba3bd9f16f8c052d4615b2e82c038b.jpg
# 29810_04_jpg.rf.a789be8eb385f6d90e8f73ddac902cc4.jpg
# 29810_15_jpg.rf.5eb686b8abc840cbdb715edbc23be2e8.jpg
# 29810_15_jpg.rf.66920b7af1912d58e17a97df097d8ef3.jpg
# 29810_15_jpg.rf.c06851d4321d457f78b5674d69111faf.jpg
# 360_F_420423986_gDrEzxqqlrw5VGWG7cr7tlwuw63k9Hxf_jpg.rf.1721ed4708b057529ea55ce76aaa6fb9.jpg
# 360_F_420423986_gDrEzxqqlrw5VGWG7cr7tlwuw63k9Hxf_jpg.rf.75c5998d2176e6fbdacfbcb854535624.jpg
# 360_F_420423986_gDrEzxqqlrw5VGWG7cr7tlwuw63k9Hxf_jpg.rf.c4efaf0fc14f1d836283d16e7b1fd806.jpg
# 360_F_488140797_G6GXw9BQAe7dSXBmBhNhUqgkMUQjtau0_jpg.rf.5f56530a2bbcca061e5f0f7e04c49445.jpg
# 360_F_488140797_G6GXw9BQAe7dSXBmBhNhUqgkMUQjtau0_jpg.rf.b4feb2e303e8c49ee53065214e458854.jpg
# 360_F_488140797_G6GXw9BQAe7dSXBmBhNhUqgkMUQjtau0_jpg.rf.dba9db412c9e6be8aee9f07ee53cd9a8.jpg
# 3939-15farmyworm_jpg.rf.557a8a9847eb016911d10ec70effc529.jpg
# 3939-15farmyworm_jpg.rf.82cbbc91575959fd7f0aefdc1a64155d.jpg
# 3939-15farmyworm_jpg.rf.b83a83b9a0a78983666b025c3bfe7bec.jpg
# 3f50a063-af57-48cf-a23a-5f761a344cfe-large16x9_PARMYWORMSINVADE-transfer_frame_3346_webp.rf.30aff68b0542756c4d83991e4413c213.jpg
# 3f50a063-af57-48cf-a23a-5f761a344cfe-large16x9_PARMYWORMSINVADE-transfer_frame_3346_webp.rf.700fc50599a6ce975facb7167e735e41.jpg
# 3f50a063-af57-48cf-a23a-5f761a344cfe-large16x9_PARMYWORMSINVADE-transfer_frame_3346_webp.rf.eda41fb9cd8728c106f84bb9a6073c5d.jpg
# 4387031_jpg.rf.468c4de8523f6abd51d6e32161110fe7.jpg
# 4387031_jpg.rf.a90a26b6881b61020cf024f8bbb90efb.jpg
# 4387031_jpg.rf.d43db28d5212da63f7838d25ed973396.jpg
# 4387058_jpg.rf.6c11e63e1c735c853f27ccfa20597d1a.jpg
# 4387058_jpg.rf.82c47b82e884dccfc1524b1564c11380.jpg
# 4387058_jpg.rf.fce05cfc9195ff1591f18d121f04a0df.jpg
# 49107_original-copy_jpeg.rf.5895b5d6980b1db04d36b1f2c7a04fe3.jpg
# 49107_original-copy_jpeg.rf.6e01dee539bc5a0883008e66c3f2b5ef.jpg
# 49107_original-copy_jpeg.rf.ab349a87b8b8fafad758465a5bdfe2b1.jpg
# 5110009_jpg.rf.273af4b66db4a3a5a78eff9193df48be.jpg
# 5110009_jpg.rf.b3166b4774bba52fd8d5380fc6594eb5.jpg
# 5110009_jpg.rf.f7bc74f7a9208bf1244d622067142694.jpg
# 5361210-Fall-Armyworm-e1497986850347_jpg.rf.392a542dd170318911580471c2a92764.jpg
# 5361210-Fall-Armyworm-e1497986850347_jpg.rf.97846a128544c549a3efcbafa0002db2.jpg
# 5361210-Fall-Armyworm-e1497986850347_jpg.rf.e7144d59c73df9957432a6e6a13e8fff.jpg
# 5485992_jpg.rf.1a9cf9cbfba785273af5929410d915ff.jpg
# 5485992_jpg.rf.82a4e93c5cbd34af3b6d2fcf17d6a398.jpg
# 5485992_jpg.rf.b94f3093b30c42e301b9be89fad7a115.jpg
# 5caaa99b50_jpg.rf.08aa1e2eeb913e3b94fd0a988b60098f.jpg
# 5caaa99b50_jpg.rf.4591c0d5ee5bb994f6f4fdca7b87138f.jpg
# 5caaa99b50_jpg.rf.be1a13b77d2caa26675b456f2629c0e1.jpg
# 61348de63d0ab-image_jpg.rf.20de4f15138114788261b7f87f9a30a4.jpg
# 61348de63d0ab-image_jpg.rf.6de641330caa99968add07600a616dc8.jpg
# 61348de63d0ab-image_jpg.rf.87149f9c7ba855bf1ff97443e30356b1.jpg
# _94646145_2_jpg.rf.058283ee51b4f908877824c5d9df1c37.jpg
# _94646145_2_jpg.rf.6226acb7fc3544ad1779e0ce3045fc5b.jpg
# _94646145_2_jpg.rf.6ac64f58754b5e85ecc224ac112d9384.jpg
# AdobeStock_423106639-1-scaled_jpeg.rf.1c2409a1ce934559f196c0bb458a30f1.jpg
# AdobeStock_423106639-1-scaled_jpeg.rf.225d9b3b41c68502f4f3910e882d4ab1.jpg
# AdobeStock_423106639-1-scaled_jpeg.rf.a0e8e514d549af1f1baafb9af8bdc9db.jpg
# african-armyworm-spodoptera-exempta-caterpillars-on-damaged-maize-B7BCN2_jpg.rf.3fee180147b3fe597ef4069ccddf43c8.jpg
# african-armyworm-spodoptera-exempta-caterpillars-on-damaged-maize-B7BCN2_jpg.rf.584c244570fc6d21558d4e97d8bd31f1.jpg
# african-armyworm-spodoptera-exempta-caterpillars-on-damaged-maize-B7BCN2_jpg.rf.5874752018b37d1d6dba08f2a09fd533.jpg
# AgronomyNews_September_2021_ManagingFallArmyworm_Fig_3_jpg.rf.6b87b548d3af5b00cefb5c34f2affc9c.jpg
# AgronomyNews_September_2021_ManagingFallArmyworm_Fig_3_jpg.rf.9dd7373947030d86faf62fd3ec18faa2.jpg
# AgronomyNews_September_2021_ManagingFallArmyworm_Fig_3_jpg.rf.9e8941b2bdaf634e3505dbdc4162239b.jpg
# Armyworm-1024x698-1_jpg.rf.21c82afa3c84d8377e91a1362f29149c.jpg
# Armyworm-1024x698-1_jpg.rf.2722e865851cbddd98dbed0638015db8.jpg
# Armyworm-1024x698-1_jpg.rf.79b0cfa9594150a616364251b09a6c94.jpg
# armyworm-1-650x488_jpg.rf.cfa787ebf93b2baa62647e200aeab06b.jpg
# armyworm-1-650x488_jpg.rf.e1115074a67d928616c81a4a00c4cfd7.jpg
# armyworm-1-650x488_jpg.rf.ff79541e1a9a48649d92474f83afdc69.jpg
# Army_Worm-1999x1200_jpg.rf.2374a5878ee173ff43f02d80a215429a.jpg
# Army_Worm-1999x1200_jpg.rf.801a6f4b4e633dd114e8910574e4017a.jpg
# Army_Worm-1999x1200_jpg.rf.bc8fefe93d276cd205d2dbbaa1ba847d.jpg
# armyworm-copy-2_jpg.rf.12d6b2514442189ed9291b780a8b7c93.jpg
# armyworm-copy-2_jpg.rf.4f299705229a3e95cbbc13d11e0605b8.jpg
# armyworm-copy-2_jpg.rf.be75edeb3a476fb09ba8d0444e5a3858.jpg
# armyworm-copy_jpg.rf.3f0dd9cdde89777482149bd333e8f318.jpg
# armyworm-copy_jpg.rf.42d4aebac2d58f45f26d84dbda3c03a4.jpg
# armyworm-copy_jpg.rf.8545d0dc33cf523b05c51eb59d023379.jpg
# armyworm_jpg.rf.33a8d730a756da5dcfa560952bbb8473.jpg
# armyworm_jpg.rf.883ffbd6e3ca18552b1191400d9a408f.jpg
# armyworm_jpg.rf.caba3a3775c33696b013bcaf56d8200f.jpg
# armyworm-on-plant-960_jpg.rf.750db0c6613654c2aae68c7c66fc04cc.jpg
# armyworm-on-plant-960_jpg.rf.792be71839b401dcd73cdfe44db1d2ad.jpg
# armyworm-on-plant-960_jpg.rf.86719c043cf4b1be80cea604152fd23c.jpg
# Armyworms-continue-their-relentless-attacks-on-crops-worldwide-_jpg.rf.b97dab818afe47af5a6fedd9755eea94.jpg
# Armyworms-continue-their-relentless-attacks-on-crops-worldwide-_jpg.rf.dee817db47d29c7bdff3c040e608996f.jpg
# Armyworms-continue-their-relentless-attacks-on-crops-worldwide-_jpg.rf.e750cce2013fb869279cce12fa44e428.jpg
# armyworms-in-texas-600x400_jpg.rf.6539e892e4575257d835de8bcea4814e.jpg
# armyworms-in-texas-600x400_jpg.rf.7c0ed9d0991ff0c090a41f6ebaa4e19d.jpg
# armyworms-in-texas-600x400_jpg.rf.f0ae6440f358ca71e7fb3912c401b42d.jpg
# armywormsplit-screen1280x720_3-recovered_webp.rf.1c7f756cdff15e373a873fc1a8bf93be.jpg
# armywormsplit-screen1280x720_3-recovered_webp.rf.2cbbd7c6002ee9f3022c5682a2435b25.jpg
# armywormsplit-screen1280x720_3-recovered_webp.rf.4dbbfe5db58c78c0afa1b28398716153.jpg
# Armyworms_webp.rf.2c087c6439b2390ded731147d283f249.jpg
# Armyworms_webp.rf.cca2f8e58ba2b16da3cd1cf6487d86ef.jpg
# Armyworms_webp.rf.f83303da2cd9226f52fce1ccc921a1ed.jpg
# armyworm-t63p61-Kansas-State-University_png.rf.511c9794a4d944f8a9b30f6467b5b2f5.jpg
# armyworm-t63p61-Kansas-State-University_png.rf.c064396d9f469a67335c0a99a446a225.jpg
# armyworm-t63p61-Kansas-State-University_png.rf.f4b6f13f966094515ddf25313e093d85.jpg
# _classes.csv
# common_armyworm_ZL_jpg.rf.3a30241452a7edd697e4a88bff800a84.jpg
# common_armyworm_ZL_jpg.rf.6a1d074cb134683a562148af7f946e88.jpg
# common_armyworm_ZL_jpg.rf.90bb0e09a7f58f1ab6cc192e903b7cdc.jpg
# common_armyworm_ZL_jpg.rf.b5f8cb205a1ba01fdffb5a48da1b0311.jpg
# common_armyworm_ZL_jpg.rf.d362378e4b8ead148c2caff651024112.jpg
# common_armyworm_ZL_jpg.rf.f5ad967d3f435cb32428705c922c238d.jpg
# dscn3849s80x45tm_0_jpg.rf.2b2b2e4513953abc88b42cf8e0062660.jpg
# dscn3849s80x45tm_0_jpg.rf.3dd73845220e140f3262021335b66267.jpg
# dscn3849s80x45tm_0_jpg.rf.e81485ce429dcd27c9aa490cb8d80e52.jpg
# ezgif-2-c7f402c52f_jpg.rf.504890adde346b94b4cfdf89d91c6027.jpg
# ezgif-2-c7f402c52f_jpg.rf.69915a073610c8be2f8c84bee946547c.jpg
# ezgif-2-c7f402c52f_jpg.rf.c8044b160176f29fbec9532834750280.jpg
# ezgif-2-cf508a23f2_jpg.rf.7eec2898a16184bcb29e4470d29c5a7d.jpg
# ezgif-2-cf508a23f2_jpg.rf.d71b78422f0b36ca352433e6030cdc55.jpg
# ezgif-2-cf508a23f2_jpg.rf.dab9b877dadac0613b508c96596cfd59.jpg
# ezgif-3-4ad299182c_jpg.rf.79afb2042cd8c848cb06f671ecd76adb.jpg
# ezgif-3-4ad299182c_jpg.rf.a947625d4eb317513cf77150d4071216.jpg
# ezgif-3-4ad299182c_jpg.rf.e05e4b1251e9cf9a171223b8149d28ea.jpg
# ezgif-3-e2b3e63c35_jpg.rf.30eb7dfad63229f51977d82061623eaa.jpg
# ezgif-3-e2b3e63c35_jpg.rf.4058b98d8fa2e4795547267fb4f9affb.jpg
# ezgif-3-e2b3e63c35_jpg.rf.a8f40d5dc053509ce16818750c759331.jpg
# ezgif-6-7b04a71e3e_webp.rf.7862175bc6310a9d064a267ef16752f6.jpg
# ezgif-6-7b04a71e3e_webp.rf.9fde541069a3fdfe311c64684630c554.jpg
# ezgif-6-7b04a71e3e_webp.rf.b62e6ee894afb44950e4c0486ada6113.jpg
# ezgif-7-5c7628e863_jpg.rf.02fecca8aa17d451a8b50706e87a9ed5.jpg
# ezgif-7-5c7628e863_jpg.rf.6aed00cbfd866526da9ae0b7b63faf8f.jpg
# ezgif-7-5c7628e863_jpg.rf.745cf68d61165e253e50f5134651ca0d.jpg
# fall-army-catepillers_jpg.rf.1babe315e533c0d5ade18aabdb907899.jpg
# fall-army-catepillers_jpg.rf.c9221bf765695cb35825cdeaa2f41dfe.jpg
# fall-army-catepillers_jpg.rf.d8944dae6d8edf08c4fa5aa51e55aafb.jpg
# fall-army-larvae2-big_jpg.rf.0e4c05e4dd650766c27b1d1d8e7b45ae.jpg
# fall-army-larvae2-big_jpg.rf.79418b565064678deb64c83346d33238.jpg
# fall-army-larvae2-big_jpg.rf.b11e6a859a47340c2d62d0d61ebec3a1.jpg
# fall_armyworm03_jpeg.rf.b60ee7627132392fbbbecd1cdbd10d9f.jpg
# fall_armyworm03_jpeg.rf.b686ed138897b8803d0cee467815f868.jpg
# fall_armyworm03_jpeg.rf.e5a6c62b9881cf248cbc5fb1cbc259f7.jpg
# fall_armyworm05_jpeg.rf.3c9ef6855a3d4527748d775c5d1827bf.jpg
# fall_armyworm05_jpeg.rf.4146970bbcdb3333eaac6cad928ed871.jpg
# fall_armyworm05_jpeg.rf.579965832838a342edb2ca97ab6a48f5.jpg
# Fall-armyworm-1_jpg.rf.2b750e27f7d7fbdcc137afb2683ad753.jpg
# Fall-armyworm-1_jpg.rf.9d5c74ee7de416a670511e568f3a1aa5.jpg
# Fall-armyworm-1_jpg.rf.adca0b3bb9e6b8cc5a329d24eab41206.jpg
# fall-armyworm-2017-uaex_jpg.rf.2258d72ea59c45e78e8a4554f1294c9a.jpg
# fall-armyworm-2017-uaex_jpg.rf.ce01fde1869d9c575031cb7e357fea96.jpg
# fall-armyworm-2017-uaex_jpg.rf.f7caa4bff44e533eb2bab80d2f2716df.jpg
# fallarmyworm2_jpg.rf.27669ca95a9b38405f3cf3811fe0cf33.jpg
# fallarmyworm2_jpg.rf.8a3a9dae1863e3b0f1617006bb223071.jpg
# fallarmyworm2_jpg.rf.f26364967d8669c0d9b53d83733460e5.jpg
# fall-armyworm-do4n_webp.rf.52a8440612c2cdc360fb6b74c1d82306.jpg
# fall-armyworm-do4n_webp.rf.798398f2edf9c73e39c367ae540c9f2e.jpg
# fall-armyworm-do4n_webp.rf.f046f13d3d41ee08a1bc412d13355e74.jpg
# fall-armyworm-fig1_jpg.rf.35c5c097298435465ba4aed34ae340f7.jpg
# fall-armyworm-fig1_jpg.rf.47e5f4d1cf013e1008fb1fa9b233785a.jpg
# fall-armyworm-fig1_jpg.rf.b05acfc7ff30abacec8684d981a8228e.jpg
# Fall-armyworm-green_jpg.rf.20ebe50f6af94a390ae665edf694efa6.jpg
# Fall-armyworm-green_jpg.rf.2dd3a5d62f1c96888e547c704061fd13.jpg
# Fall-armyworm-green_jpg.rf.deb626731b4fdd16735379bc8ef79b2f.jpg
# fall-armyworm-IMG_6969-sm_jpg.rf.5fd3234924da08b0fc6cca59681f429f.jpg
# fall-armyworm-IMG_6969-sm_jpg.rf.947b1cde33b25f6cf890c45f13a8ba5e.jpg
# fall-armyworm-IMG_6969-sm_jpg.rf.c9d3bbe12b9e0f846767216bef32de4d.jpg
# fall-armyworm-IMG_6978b-sm_jpg.rf.5b5d8da6b5e8402dcd9bcbbe088b0b70.jpg
# fall-armyworm-IMG_6978b-sm_jpg.rf.c3f901db923f0ba0116ead5497a8736e.jpg
# fall-armyworm-IMG_6978b-sm_jpg.rf.e4da06f26d46f1438b517b931b5bdd4e.jpg
# Fall-army-worm_jpg.rf.02a53b8690b637cc4ad613894b9204e8.jpg
# Fall-army-worm_jpg.rf.4666b51a1d2901d1513df11db86a9002.jpg
# Fall-army-worm_jpg.rf.ade540876481839ee5d39600680a48a9.jpg
# Fall-Armyworm-larva-JFD_jpg.rf.4a520c89d70503de079a62025f1bca1b.jpg
# Fall-Armyworm-larva-JFD_jpg.rf.5631f4e128e01f30b87f2ceb796c92f3.jpg
# Fall-Armyworm-larva-JFD_jpg.rf.6448def1cf19a1a7229b54a25bc131ca.jpg
# fall-armyworm-larva_jpg.rf.abbc232ea0e218cc5061a895d5a2e18d.jpg
# fall-armyworm-larva_jpg.rf.c1750f742c46300ed00933c72bb0e8a3.jpg
# fall-armyworm-larva_jpg.rf.d5f64c7ba55622a563d823a4b663ad27.jpg
# Fall-Armyworm-larva_png.rf.6c87818265eae14d2a75daf66abeaeed.jpg
# Fall-Armyworm-larva_png.rf.a3c66399238aa5d8f646b9082413a7b6.jpg
# Fall-Armyworm-larva_png.rf.cf661507279b4fe6f70914504a0b7d0d.jpg
# fall_armyworm_lv_rh_jpg.rf.58adccc39cd5ec732b2f2f7cc6b66f20.jpg
# fall_armyworm_lv_rh_jpg.rf.dc09647e87f35892f6db1f6a96dfd509.jpg
# fall_armyworm_lv_rh_jpg.rf.fc55640285fcd228c62b3cb210ecfcca.jpg
# fall-armyworm-on-grass-blade_jpg.rf.a87a47b09dd5f7663ae52f0f87a6655c.jpg
# fall-armyworm-on-grass-blade_jpg.rf.da0da719b01d71bbdfc23ae2031e90d3.jpg
# fall-armyworm-on-grass-blade_jpg.rf.e7dbc8dd5d4d4e816f1acc5a4201d5dd.jpg
# fall-army-worm-on-potato-1-_jpg.rf.31a6ad16bf9119f79401a6c2ea8a826b.jpg
# fall-army-worm-on-potato-1-_jpg.rf.4693be4fb78b9f25c885942cdb9311af.jpg
# fall-army-worm-on-potato-1-_jpg.rf.a64a754ea543f299d1bbc5e03d642e02.jpg
# fall-army-worm-on-potato-4-_jpg.rf.7eb56bca7db5d36f4cf8248ba75ad477.jpg
# fall-army-worm-on-potato-4-_jpg.rf.7ff5b5d678d77fb75d6ebe5186646cd7.jpg
# fall-army-worm-on-potato-4-_jpg.rf.863e7e31b27169c93ee2b6bedf7d03f6.jpg
# fall-army-worm-on-potato-5-_jpg.rf.0a996b5d119389dd034ca4178d887c03.jpg
# fall-army-worm-on-potato-5-_jpg.rf.1298ede58d48f720402832f6b99d890c.jpg
# fall-army-worm-on-potato-5-_jpg.rf.e2505cd78a59649358ebc29a5d8b69ac.jpg
# fall-army-worm-on-potato-6-_jpg.rf.1764d069caebb6542868f9ed4de93247.jpg
# fall-army-worm-on-potato-6-_jpg.rf.9c93277c9e46290d81f04fba81d670ac.jpg
# fall-army-worm-on-potato-6-_jpg.rf.aee3b184565ca72da55246444d5b52bd.jpg
# FallArmyworm_png.rf.314711991b8f6db092eeee46dba7e980.jpg
# FallArmyworm_png.rf.5e50b7b1dcefa06a6218478c273dc4e2.jpg
# FallArmyworm_png.rf.e7e7192327f4491145dfb08bfbfddcf5.jpg
# Fall-armyworm-update-F01_jpg.rf.1af42c85d5f1096fb06ad9bd58e6bd43.jpg
# Fall-armyworm-update-F01_jpg.rf.2b2fb8d7298c1a6444c37a89eb92d92d.jpg
# Fall-armyworm-update-F01_jpg.rf.9d042fa5e1d6ed2a86268906d8631304.jpg
# FAO_A-Fall-Armyworm-on-a-maize-plant-in-Sri-Lanka_photo-cred-FAO_jpg.rf.18ba34420a6c0ef143ff81b666ac4f42.jpg
# FAO_A-Fall-Armyworm-on-a-maize-plant-in-Sri-Lanka_photo-cred-FAO_jpg.rf.3e13ca70e46876e1eef4dbbdc4b585f1.jpg
# FAO_A-Fall-Armyworm-on-a-maize-plant-in-Sri-Lanka_photo-cred-FAO_jpg.rf.b9c27b86e99869b12a7e70576e3e1024.jpg
# FAW2_jpg.rf.37595b3a499adde490786ce939562a85.jpg
# FAW2_jpg.rf.b405d859a1c41aae65da3ba54edded4c.jpg
# FAW2_jpg.rf.da500d99f9bdfe4ee9d4bdedb192ddc2.jpg
# faw-800x400_jpg.rf.0fe8e71b78727831bd712f01443465b4.jpg
# faw-800x400_jpg.rf.29db3815defdf9afe3653dfc6d39a9f6.jpg
# faw-800x400_jpg.rf.ddb8746f09b3b818e5f67e212526fff9.jpg
# faw-different-colours-same-field_jpg.rf.33305155417237dad9b9338cc2378236.jpg
# faw-different-colours-same-field_jpg.rf.376602920658f8c84733c18e569bd505.jpg
# faw-different-colours-same-field_jpg.rf.613962ebca82da32b3e6ecc4d84bf19b.jpg
# FAW_head_corn_jpg.rf.6adaaa3a2a70b6428e7ba971812bf7e4.jpg
# FAW_head_corn_jpg.rf.8768567420f55936e9da3703554fc1a9.jpg
# FAW_head_corn_jpg.rf.f1972b21d1cf96cd738bfc590d6aa0d1.jpg
# FAW_head_corn-pe4vmtd621c9kfsuqne5s9c7ytutttwzxn69v3mwgi_jpg.rf.2ef6a2b3caf63c77f246350e9d80b573.jpg
# FAW_head_corn-pe4vmtd621c9kfsuqne5s9c7ytutttwzxn69v3mwgi_jpg.rf.3fee78cd4063f37bb3d8165f4951faf9.jpg
# FAW_head_corn-pe4vmtd621c9kfsuqne5s9c7ytutttwzxn69v3mwgi_jpg.rf.dcfc7b975b74e5b93be949f9fdcac12d.jpg
# fawJPG_jpg.rf.0977c6157277db202db412f05daefb71.jpg
# fawJPG_jpg.rf.39127e4ac2f55f77f3823a72352453c5.jpg
# fawJPG_jpg.rf.7942804f876e6fbabc593264c6c7a3de.jpg
# FAW-larva-in-KRS-corn-1-4-2020_png.rf.24825ab865358cb0ab0fe25cafaa308c.jpg
# FAW-larva-in-KRS-corn-1-4-2020_png.rf.815da9d42ff0eda380794ff7d9808ea2.jpg
# FAW-larva-in-KRS-corn-1-4-2020_png.rf.aa31212f36406814a5fa8c03de807dfa.jpg
# FAWormsDenudedAlfalfaHay_Shelton72_jpg.rf.51732ad44ec77d19e495b6549e919497.jpg
# FAWormsDenudedAlfalfaHay_Shelton72_jpg.rf.b4c4ce1d7cb0984c63ac1c426fa62462.jpg
# FAWormsDenudedAlfalfaHay_Shelton72_jpg.rf.cdf0e52ec67c2961806de4178c5105cd.jpg
# FAW-TN-1-_jpg.rf.3bcad30823fe8cbad54b245bd3134fc4.jpg
# FAW-TN-1-_jpg.rf.5441b9227cdd8edee119bea895daa351.jpg
# FAW-TN-1-_jpg.rf.606092ec634150361071e9191e608794.jpg
# FAW-TN-2-_jpg.rf.04ef9463cbf3657a95325af6e1733331.jpg
# FAW-TN-2-_jpg.rf.09ce91ff304b0950e72a26389f2012c8.jpg
# FAW-TN-2-_jpg.rf.7c5e7a22960bbaf1cb166efce96fc891.jpg
# first_instar_fall_armyworm_png.rf.0e2f425c9dd4f572b07685198bad9f8c.jpg
# first_instar_fall_armyworm_png.rf.9aeb68c92a6213fedc20a2407fd7cdbd.jpg
# first_instar_fall_armyworm_png.rf.ed466deb2cf72d4feda5eb6d28ee9553.jpg
# grubs_webp.rf.3a315d79295f57c5317fb0bd5b238eed.jpg
# grubs_webp.rf.637ffb63f51a2173b647f2c206bacc6f.jpg
# grubs_webp.rf.dd40a8f42c688f9d9b25406ff03af91e.jpg
# image_jpg.rf.a8b8e3921425372115eb7c221d53084e.jpg
# image_jpg.rf.e23e8d90f6e3ea524d5a911fe969a511.jpg
# image_jpg.rf.e717c7b776c632d4785dc1c19576f10d.jpg
# images_jpeg.rf.3e7075eb57b099e6dadacd1d095bc89f.jpg
# images_jpeg.rf.85086c6f31cf3f643a6d02ba353814ec.jpg
# images_jpeg.rf.e56074aeb108b95d9a07152654758073.jpg
# IMG_2641-01_jpg.rf.0186ff1911e95bf5db02312b21a06ac8.jpg
# IMG_2641-01_jpg.rf.3c500272cad8413b1c059f2abcd19a64.jpg
# IMG_2641-01_jpg.rf.e6f60f55c692ec5bceda840ebc678cce.jpg
# img321_jpg.rf.3456aa93d8ca944964d137788a3b3788.jpg
# img321_jpg.rf.43037cd72b0891996c3ef25e0bf417de.jpg
# img321_jpg.rf.b23193f12250838ed7caa06bac0d72e2.jpg
# IMG_9858-scaled-1-1024x656_jpg.rf.320e5c922605cd3b2fdfd8682f6190df.jpg
# IMG_9858-scaled-1-1024x656_jpg.rf.b8457a6150934f1366a8ad5b065389d8.jpg
# IMG_9858-scaled-1-1024x656_jpg.rf.e893abf50c67006a80eb721b16dcc713.jpg
# ISCA-fall-armyworm_jpg.rf.426538628d8c33eeb37fe3735b0efb9c.jpg
# ISCA-fall-armyworm_jpg.rf.9801e103a8e3b2cbc9052dd1d7c8c574.jpg
# ISCA-fall-armyworm_jpg.rf.c01d3208252a89260231e634685b5f2d.jpg
# ISC-fall-armyworm_jpg.rf.0f8322fabd1f806379822bc75fe8943a.jpg
# ISC-fall-armyworm_jpg.rf.3dd41ffee48e6f50fbe9802bdc2a06ee.jpg
# ISC-fall-armyworm_jpg.rf.9887f56732dd5af92c941fb8d35271aa.jpg
# istockphoto-1163856076-612x612_jpg.rf.111f232bf8bfc786ed7af8a691e07677.jpg
# istockphoto-1163856076-612x612_jpg.rf.c7c1cc8c379a1c6fd1d0cb29e805501a.jpg
# istockphoto-1163856076-612x612_jpg.rf.c94e4a5ee7f68b2fa88a7cc839b212f1.jpg
# SCR-20240421-bnku_jpeg.rf.4275dee8e966a840be7d4cf8aa73b425.jpg
# SCR-20240421-bnku_jpeg.rf.4d968eba8f485a065d0a9870af0a134e.jpg
# SCR-20240421-bnku_jpeg.rf.88c68e4bf7d031716cd070f82c15da99.jpg
# SCR-20240421-chfe_png.rf.09a480b1f24a039f0910ab4da0464a58.jpg
# SCR-20240421-chfe_png.rf.362a791aa398b63f37cfe9a683e8f86b.jpg
# SCR-20240421-chfe_png.rf.425deaf03ffd4e6804d8c745a608955b.jpg
# S-frugiperda-larva-feeding-on-a-young-cotton-boll_png.rf.3eaf307f0bce67d90220b5457c8f58a1.jpg
# S-frugiperda-larva-feeding-on-a-young-cotton-boll_png.rf.7cc7165487777f243441465bbd481e2a.jpg
# S-frugiperda-larva-feeding-on-a-young-cotton-boll_png.rf.927647d7e9633ff481579712aa0a0233.jpg
# shutterstock_armyworms_webp.rf.05b3517645c74ee95ba5875c64da0322.jpg
# shutterstock_armyworms_webp.rf.d629ac2857abe542aef0026c0a8bc256.jpg
# shutterstock_armyworms_webp.rf.f9964426fff23877f309eb9de090861f.jpg
# sweetcorn_FAW_1_zoom_jpg.rf.757527309107d6205a06c8375a481e74.jpg
# sweetcorn_FAW_1_zoom_jpg.rf.9a509f940cb26fea8ebc4d1a18fa6d9d.jpg
# sweetcorn_FAW_1_zoom_jpg.rf.f6e0d8fbd0fbbd5a0956588f47b52ad8.jpg
# U7ZT2CVNWRX7VQZE2YTG7WEK4A_jpg.rf.45ebaf5bab7271778d3aa5e56f3006da.jpg
# U7ZT2CVNWRX7VQZE2YTG7WEK4A_jpg.rf.aa88a2b77f8507f980d6bb657d204760.jpg
# U7ZT2CVNWRX7VQZE2YTG7WEK4A_jpg.rf.b789f7721cb4b25413e94d7424095e0d.jpg
# worms_webp.rf.a8d542708e3994bf06edbef1e39d253e.jpg
# worms_webp.rf.aa96f40092e1227a5ca01544f67f4ae2.jpg
# worms_webp.rf.dcf72211658263c42cb4ac8e09084323.jpg
# YOUNG-fall_Armyworm_in_oats002_jpg.rf.22bf32bbb597f7f68bf508fa158de83e.jpg
# YOUNG-fall_Armyworm_in_oats002_jpg.rf.64d7c5cf2ea798c6bb5845006d990a33.jpg
# YOUNG-fall_Armyworm_in_oats002_jpg.rf.69a0f016cb9c6f33a912314a67b3290a.jpg
# ZL8ZSLGZ4LBHNHLR5HDH5HTH5HOHKLDHGHAH2HBZSLOHSLCHKL6ZLL5ZMHPZ0L6Z7H8ZZL6Z4LWZWHYH8LEZ0LTHNHLR_jpg.rf.414c6d125a19ffe82064407dc212ed5f.jpg
# ZL8ZSLGZ4LBHNHLR5HDH5HTH5HOHKLDHGHAH2HBZSLOHSLCHKL6ZLL5ZMHPZ0L6Z7H8ZZL6Z4LWZWHYH8LEZ0LTHNHLR_jpg.rf.d24be056079508936ab8e2e483ad9dad.jpg
# ZL8ZSLGZ4LBHNHLR5HDH5HTH5HOHKLDHGHAH2HBZSLOHSLCHKL6ZLL5ZMHPZ0L6Z7H8ZZL6Z4LWZWHYH8LEZ0LTHNHLR_jpg.rf.e1cf5832bbc866fd1bd05c9a918c02b4.jpg
#
# 'fall armyworm identification/fall armyworm identification/valid':
# 1600102_jpg.rf.e8d508e45433a3ee1bd2ddabe2aedc9f.jpg
# 200522-Fall-armyworm-pic-002-in-maize-scaled_jpg.rf.eda2e493fbbc75f62a89d1be64874e63.jpg
# 360_F_551992367_C6ETgoAyvEb8iX582SDOKuo81gWAOA63_jpg.rf.c40ac17e7a7e83073777bf3d5cb007d9.jpg
# 40538_2022_341_MOESM2_ESM_jpg.rf.65b496fe327ac0cd57781c60af78c3c0.jpg
# 48045734022_5fee84972f_o-1_jpg.rf.8a8f146737f11d6d3d57f3b8e15da975.jpg
# army4_jpg.rf.b12323154d4236a300d4264f7be0d46f.jpg
# armyworm2-24_jpg.rf.9edb3ec91978bafca84f7d04b23230b3.jpg
# armywormsdev_jpg.rf.670ccde18ad60ff02a44feb1af500fee.jpg
# armyworm-soap-flush-Caleb-Kearney_webp.rf.0f474b613a7f0c63a4929fc4498e6ea6.jpg
# armyworms-spodoptera-spp-can-be-easily-identifi_jpeg.rf.88438f206050effb68660fd6c212a5c0.jpg
# banner-fall-armyworm-6-1200x799_jpg.rf.eeb73cdaf4a53bf1d6ef5545d6824604.jpg
# _classes.csv
# csm_News_18_23_Armyworm_3ae1178757_webp.rf.3b77a2bfcaa3891834bd5fcad1bf8278.jpg
# csm_News_30_19_dd6e79c78a_webp.rf.a894cdebdca083ec9bb1f07b9ed3accd.jpg
# FallArmyWom1_jpg.rf.eb624281bbe99b6d17f93985bf295a4b.jpg
# Fall-armyworm2_jpeg.rf.04cfe1fe908d8d0baf93834955da37f3.jpg
# fall-armyworm_jpg.rf.6bab73e49852a4a2adb289c03c28cf69.jpg
# fall-armyworm-Pat-Porter-2016_jpg.rf.ca6ca86155e1089c242fc3b60f31cdd4.jpg
# fall-armyworm-spodoptera-frugiperda-on-600nw-1444285085_webp.rf.16d9231603e374339b1619ba6b9e7da5.jpg
# fall-armyworm_webp.rf.3a68c0fa636b3527640950d2f3cacecc.jpg
# faw1_jpg.rf.9a3293b586e2e9a4ebf00e25237b2b91.jpg
# FAW-in-late-corn-3_jpeg.rf.11f163b925cba93670247447933140a3.jpg
# faw-news-large_jpg.rf.7fc75520484a20cae1b3323de02ecc97.jpg
# GetStoredImage_jpeg.rf.131bcdea63a8f9e2e26d65bb2a6800c7.jpg
# image1170x530cropped_jpg.rf.b936dfde62fff13d28cd683509a68fc9.jpg
# IMG_9860_jpg.rf.8643c135161717f1d585c56cf8554ffb.jpg
# IMG_FAWLR-848x565_jpg.rf.e58fc81196f019301b21ec3ddacce93d.jpg
# LABAUR4I3JIUNK7CKHVBGRPKRY_jpg.rf.8dc4dce15d0e5ae0359c68e206c356b0.jpg
# Lawn-Armyworm-Spodoptera-mauritia-1_webp.rf.69a7fb957e76246fca812786d61d3289.jpg
# LM1021_fall-armyworm5aR_620px_jpg.rf.575cdf52d3ffd12b39b5fee9c5500ba6.jpg
# Mythimna-unipuncta_jpg.rf.cf21d61d51826961dae11da1b981ad6d.jpg
# NQ301QO0VQHS1QDK0KCKUQY05QWK8QT0GQO0ZKV0HK6K4QD0HKBKIK30UQLSIKEKPQA06QV04QB0QK_jpg.rf.649d4677eedf587ba34b23c6200e8a6c.jpg
# TurfAug22-TCArmyWorms-Feature_jpg.rf.4b011ce881ee16f106cf928cf364ceed.jpg

# %% [markdown]
# 2. Model Building (Modified Output Layer)

# %%
import tensorflow as tf # Added import as a failsafe

# Define core parameters (Added as failsafe - should be defined in the first cell)
IMG_WIDTH = 224 # Standard size for MobileNetV2
IMG_HEIGHT = 224

# Load the MobileNetV2 base model
base_model = tf.keras.applications.MobileNetV2(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
                                               include_top=False, # Exclude the classification layer
                                               weights='imagenet')

# Freeze the base model to prevent the weights from being updated during training
base_model.trainable = False


# 3. Create the Keras Sequential Model with a custom classification head
model = tf.keras.Sequential([
    tf.keras.layers.Lambda(tf.keras.applications.mobilenet_v2.preprocess_input,
                           input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)), # Wrap preprocess_input in a Lambda layer
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    # Output Layer: 1 unit with sigmoid activation for Binary Classification
    tf.keras.layers.Dense(1, activation='sigmoid') # <<< KEY CHANGE: 1 unit and 'sigmoid'
])

print("\n--- Model Summary ---")
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
#
# --- Model Summary ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/lambda_layer.py:65: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lambda_3 (Lambda)               │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,081 (9.24 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# 3. Compile, Train, and Evaluate (Modified Compilation)

# %%
import tensorflow as tf # Added import as a failsafe

# Define core parameters (Added as failsafe - should be defined in the first cell)
IMG_WIDTH = 224 # Standard size for MobileNetV2
IMG_HEIGHT = 224

# Define metrics required by the project
METRICS = [
    'accuracy',
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
]

# 1. Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy', # <<< KEY CHANGE: Use 'binary_crossentropy'
    metrics=METRICS
)

# ... (The rest of the training and evaluation code remains the same) ...
